# %% [markdown]
# # Example on How to Use the STAR-package

# %%
from star import *

# %% [markdown]
# ## If you want to see a function's documentation,
# 1) help(function_name), or go to 2) [API](https://ludvigdoeser.github.io/stasp/index.html)

# %% [markdown]
# **To access the Lightcurve-functions, don't forget to write lightcurve.function_name**

# %%
help(lightcurve)
# Out:
# Help on class lightcurve in module star.Lightcurve:
#
# class lightcurve(builtins.object)
#  |  lightcurve(filename, keywords=[], p=0)
#  |
#  |  Make a light curve object from fits-file.
#  |
#  |  **Parameters**:
#  |
#  |  `filename`: string
#  |      The path to the .fits-file. If an empty string is given, a lightcurve object will
#  |      be initiated without values for its attributes.
#  |
#  |  `keywords`: list of strings
#  |      Keywords (and corresponding values) apart from the ones mentioned below to return.
#  |      All data-keys are always automatically returned (for a lightcurve, these are: {"TIME", "RATE", "ERROR","FRACEXP"}).
#  |      Note also that the header-keys {"CONTENT","OBJECT"} are returned if they exist.
#  |
#  |  `p`: boolean
#  |      If True, print the headers of the fits-file.
#  |
#  |  **Attributes**:
#  |
#  |  `t`: np.ndarray
#  |      Time vector (in seconds).
#  |
#  |  `rate`: np.ndarray
#  |      Rate vector (in counts/s).
#  |
#  |  `err`: np.ndarray
#  |      Error vector in rate (in counts/s).
#  |
#  |  `fracexp`: np.ndarray
#  |      Fractional exposure for each bin (in percent).
#  |
#  |  `object`: string
#  |      Object for which we have constructed the lightcurve object.
#  |
#  |  `dt`: float
#  |      Time resolution (in seconds).
#  |
#  |  `R`: np.float
#  |      Mean count rate.
#  |
#  |  `N`: int
#  |      Number of data points in observation.
#  |
#  |  `Fvar`: float
#  |      Fractional variance amplitude (=rms) computed from the light curve.
#  |
#  |  `Emin, Emax`: floats
#  |      Min and max energies of used energy band.
#  |
#  |  `deltaE`: float
#  |      Energy range between min and max channels used.
#  |
#  |  `E_mean`: float
#  |      Energy mean over the range between min and max channels used.
#  |
#  |  Methods defined here:
#  |
#  |  Fvar_from_lc(self, m, percent_limit=0)
#  |      Calculate the fractional root mean square (rms) variability amplitude from
#  |      the variance (S^2) in the light curve, by averaging over K=int(np.floor(lc.N/m)) segments.
#  |
#  |  __init__(self, filename, keywords=[], p=0)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  channel_to_energy_XTE(self, channel_to_kev)
#  |      Channel to corresponding energy for XTE-data.
#  |
#  |      **Parameters**:
#  |
#  |      `channel_to_kev`: np.ndarray
#  |          Conversion from channel (index) to energy (keV).
#  |
#  |  extract_lc(self, filename, keywords, p)
#  |      Extract light curve from .fits-file. For more info, see class doc.
#  |
#  |  extract_seg(self, m, n=0, bins_back=0, to_print=False, to_plot=False)
#  |      Extract (and potentially display) a light curve segment.
#  |
#  |      **Parameters**:
#  |
#  |      `m`: int
#  |          Number of time bins per segment.
#  |
#  |      `n`: int, optional, default: 0
#  |          The start (end) of the segment will be bin number m*n (m*(n+1))
#  |
#  |      `bins_back`: int, optional, default: 0
#  |          Number of bins the segment will be moved backwards in the light curve.
#  |
#  |      `to_print`: boolean, optional, default: False
#  |          If True, prints out average count rate, totalt counts, and total time of segment.
#  |
#  |      `to_plot`: boolean, optional, default: False
#  |          If True, plot the segment.
#  |
#  |      **Returns**:
#  |
#  |      `t_seg, rate_seg, err_seg`: np.ndarrays
#  |          Time, rate, and error vectors for the segment.
#  |
#  |      `N_gamma, R, T`: floats
#  |          Number of photons (in counts), mean count rate (in counts/s) and length (in seconds) respectively.
#  |
#  |  find_energyband(self, f)
#  |      Find Emin and Emax from filename f. For more info, see class doc.
#  |
#  |  plot(self, m=0, n=0)
#  |      Display the full lightcurve.
#  |
#  |      **Parameters**:
#  |
#  |      `m`: int, optional, default = 0
#  |          Number of time bins per segment.
#  |
#  |      `n`: int, optional, default: 0
#  |          The n:th segment will be displayed in the full light curve.
#  |
#  |  rebin(self, dt=1, force=False)
#  |      Rebin light curve into new time resolution. Note: inefficient...
#  |      Better to extract new light curves using XSELECT.
#  |
#  |      **Parameters**:
#  |
#  |      `dt`: float, optional, default: 1 (sec)
#  |          New time resolution.
#  |
#  |      `force`: boolean, optional, default: False
#  |          If True, don't ask for permission to make time resolution changes
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %% [markdown]
# **To access the Lightcurve-functions, don't forget to write lightcurve.function_name**

# %%
help(lightcurve.extract_seg)
# Out:
# Help on function extract_seg in module star.Lightcurve:
#
# extract_seg(self, m, n=0, bins_back=0, to_print=False, to_plot=False)
#     Extract (and potentially display) a light curve segment.
#
#     **Parameters**:
#
#     `m`: int
#         Number of time bins per segment.
#
#     `n`: int, optional, default: 0
#         The start (end) of the segment will be bin number m*n (m*(n+1))
#
#     `bins_back`: int, optional, default: 0
#         Number of bins the segment will be moved backwards in the light curve.
#
#     `to_print`: boolean, optional, default: False
#         If True, prints out average count rate, totalt counts, and total time of segment.
#
#     `to_plot`: boolean, optional, default: False
#         If True, plot the segment.
#
#     **Returns**:
#
#     `t_seg, rate_seg, err_seg`: np.ndarrays
#         Time, rate, and error vectors for the segment.
#
#     `N_gamma, R, T`: floats
#         Number of photons (in counts), mean count rate (in counts/s) and length (in seconds) respectively.

# %% [markdown]
# # Import FITS-file:
# **Pick a filename or use the default for this demonstration (press enter)**

# %%
filename = input('Path to FITS-file (press enter for default): ') or "Data/MAXIJ1535_571/1050360103/5to5.5kev.lc"
clear_output(True) #to remove the above input-line
data = extract_fits(filename)
# Out:
# Loading fits from filename:  Data/MAXIJ1535_571/1050360103/5to5.5kev.lc
# There is no content-information for this fits.
# The keys to the data are: dict_keys(['TIME', 'RATE', 'ERROR', 'FRACEXP', 'OBJECT'])
# Loading fits done.

# %% [markdown]
# **We can put p=1 to print out all headers:**

# %%
data = extract_fits(filename,p=1)
# Out:
# Loading fits from filename:  Data/MAXIJ1535_571/1050360103/5to5.5kev.lc
# There is no content-information for this fits.
# hdu.info()
# Filename: Data/MAXIJ1535_571/1050360103/5to5.5kev.lc
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      36   ()
#   1  RATE          1 BinTableHDU    312   26598R x 4C   ['D', 'E', 'E', 'E']
#   2  GTI           1 BinTableHDU     50   3R x 2C   [1D, 1D]
# None
#
# Header0:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                   32 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# TELESCOP= 'NICER   '           / Telescope (mission) name
# DATAMODE= 'PHOTON  '           / Datamode
# DETNAM  = 'NONE    '           / Detector
# INSTRUME= 'XTI     '           / Instrument name
# OBJECT  = 'MAXI_J1535-571'     / Name of observed object
# ONTIME  = 1.330000000000000E+02 / On-source time
# EXPOSURE= 1.330000000000000E+02 / Exposure time
# LIVETIME= 1.330000000000000E+02 / On-source time
# DATE-OBS= '2017-09-09T07:14:11' / Start date of observations
# DATE-END= '2017-09-09T10:25:20' / End date of observations
# TSTART  = 1.164071520000000E+08 / time start
# TSTOP   = 1.164183210000000E+08 / time stop
# TELAPSE = 1.116900000000000E+04 / elapsed time
# MJD-OBS = 5.800530577759259E+04 / MJD of data start time
# MJDREFI =                56658 / MJD reference day
# MJDREFF = 7.775925925925930E-04 / MJD reference (fraction of day)
# TIMEREF = 'LOCAL   '           / reference time
# TIMESYS = 'TT      '           / time measured from
# TIMEUNIT= 's       '           / unit for time keywords
# EQUINOX =            2.000E+03 / Equinox of celestial coord system
# RADECSYS= 'FK5     '           / celestial coord system
# USER    = 'ludde   '           / User name of creator
# FILIN001= 'ni1050360103_0mpu7_cl.evt' / Input file name
# CREATOR = 'extractor v5.39'    / Extractor version
# DATE    = '2021-12-08T09:40:53' / file creation date (YYYY-MM-DDThh:mm:ss UT)
# ORIGIN  = 'NASA/GSFC'          / origin of fits file
# TIMEDEL = 4.999999900000000E-03 / Binning factor
# HISTORY extractor v5.39
# CHECKSUM= 'gobPgnZOgnaOgnYO'   / HDU checksum updated 2021-12-08T09:40:53
# DATASUM = '         0'         / data unit checksum updated 2021-12-08T09:40:53
#
# Header1:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                   20 / width of table in bytes
# NAXIS2  =                26598 / Number of bins
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                    4 / number of fields in each row
# TTYPE1  = 'TIME    '           / label for field   1
# TFORM1  = 'D       '           / data format of field: 8-byte DOUBLE
# TUNIT1  = 's       '           / physical unit of field
# TTYPE2  = 'RATE    '           / label for field   2
# TFORM2  = 'E       '           / data format of field: 4-byte REAL
# TUNIT2  = 'count/s '           / physical unit of field
# TTYPE3  = 'ERROR   '           / label for field   3
# TFORM3  = 'E       '           / data format of field: 4-byte REAL
# TUNIT3  = 'count/s '           / physical unit of field
# TTYPE4  = 'FRACEXP '           / label for field   4
# TFORM4  = 'E       '           / data format of field: 4-byte REAL
# EXTNAME = 'RATE    '           / name of this binary table extension
# HDUCLASS= 'ogip    '           / Format conforms to OGIP/GSFC conventions
# HDUCLAS1= 'LIGHTCURVE'         / Extension contains a light curve
# DATAMODE= 'PHOTON  '           / Datamode
# DATE    = '2021-12-08T09:40:53' / file creation date (YYYY-MM-DDThh:mm:ss UT)
# EXPOSURE= 1.330000000000000E+02 / Exposure time
# ONTIME  = 1.330000000000000E+02 / On-source time
# TIMEPIXR= 5.000000000000000E-01 / Timestamps give center of bin
# TIMEDEL = 4.999999900000000E-03 / Binning factor
# TIMEZERO= 1.164071520025000E+08 / Time Zero
# COMMENT   DEADTIME is approximate MPU deadtime on a per-event basis. Each MPU
# COMMENT   is independent of the others.  MPU dead-time is quantized in steps
# COMMENT   of 620.2 ns.  True dead time may be anywhere within this step, but
# COMMENT   this FITS file records the center of the range. The dead-time value is
# COMMENT   truncated at 79075.5 ns; the true dead-time may be larger.
# COMMENT   EVENT_FLAGS is a bit pattern with MPU-derived information flags
# COMMENT   (EVENT_FLAGS == bxx1xxxxx) First X-ray event in an MPU photon packet
# COMMENT   (EVENT_FLAGS == bxxx1xxxx) Slow channel triggered
# COMMENT   (EVENT_FLAGS == bxxxx1xxx) Fast channel triggered
# COMMENT   (EVENT_FLAGS == bxxxxx1xx) Externally triggered pulse height sample
# COMMENT   (EVENT_FLAGS == bxxxxxx1x) Hardware-detected overshoot
# COMMENT   (EVENT_FLAGS == bxxxxxxx1) Hardware-detected undershoot
# COMMENT   $Id: a99ed4d43315e38878d3690ddf900e312cd38ce6 $
# TELESCOP= 'NICER   '           / Telescope (mission) name
# INSTRUME= 'XTI     '           / Instrument name
# TARG_ID =                 1922 / NICER target catalog ID number
# OBSERVER= 'GENDREAU, KEITH C.' / Observer or Principal Investigator
# TITLE   = 'BURST / ACCRETION WORKING GROUP' / Science program title
# OBS_ID  = '1050360103'         / Observation ID
# ORIGIN  = 'NASA/GSFC'          / origin of fits file
# CREATOR = 'extractor v5.39'    / Extractor
# TLM2FITS= 'NICER2FITSv1.18_FSWv20170404a' / Telemetry converter version number
# PROCVER = 'l0-master_20180226' / Processing script version number
# SOFTVER = 'Hea_10Oct2017_V6.22.1_NICER_2018-03-01_V003' / HEASoft software versi
# CALDBVER= 'xti20180226'        / CALDB index versions used
# SEQPNUM =                    2 / Number of times the dataset processed
# OBJECT  = 'MAXI_J1535-571'     / Name of observed object
# EQUINOX =            2.000E+03 / Equinox of celestial coord system
# RADECSYS= 'FK5     '           / celestial coord system
# RA_NOM  =             233.8336 / [deg] R.A. of nominal aspect point [J2000]
# DEC_NOM =            -57.23175 / [deg] Dec. of nominal aspect point [J2000]
# RA_OBJ  =              233.833 / [deg] R.A. of target [J2000]
# DEC_OBJ =             -57.2313 / [deg] Dec. of target [J2000]
# TIMESYS = 'TT      '           / time measured from
# MJDREFI =                56658 / MJD reference day
# MJDREFF = 7.775925925925930E-04 / MJD reference (fraction of day)
# TIMEREF = 'LOCAL   '           / reference time
# TASSIGN = 'SATELLITE'          / Time assigned by clock
# TIMEUNIT= 's       '           / unit for time keywords
# TIERRELA=               1.0E-8 / [s/s] relative errors expressed as rate
# TIERABSO=                  1.0 / [s] timing  precision  in seconds
# TSTART  = 1.164071520000000E+08 / time start
# TSTOP   = 1.164183210000000E+08 / time stop
# DATE-OBS= '2017-09-09T07:14:11' / Start date of observations
# DATE-END= '2017-09-09T10:25:20' / End date of observations
# CLOCKAPP=                    T / Clock correction has been applied
# DEADAPP =                    F / Has DEADC been applied to data?
# LEAPINIT=                  0.0 / [s] Number of leap seconds at TSTART
# MPUTICKR=            25803540. / [Hz] Nominal MPU tick rate (custom)
# MPUTICKM= 'PREVIOUS'           / Use previous PPS to adjust MPU tick rate
# MPUTIMEM= 'PREVIOUS'           / Extraplate MPU time from previous PPS
# MPU_ID  =                    0 /  Selected MPU number
# HISTORY CFITSIO used the following filtering expression to create this table:
# HISTORY ./1050360103/xti/event_uf/ni1050360103_0mpu0_uf.evt[EVENTS][(gtifilter("
# HISTORY ./1050360103/xti/event_cl/ni1050360103_0mpu0_ufa.evt_filt-evgti.gti",TIM
# HISTORY E)&&(EVENT_FLAGS == bxxxx00))]
# HISTORY
# HISTORY START PARAMETER list for ftmerge_2.20 at 2018-03-06T19:16:03
# HISTORY
# HISTORY P1 (infile = @./1050360103/xti/event_cl/ni1050360103_0mpu0_ufa.evt_filt-
# HISTORY P1 events.lis)
# HISTORY
# HISTORY START FILE listing: ni1050360103_0mpu0_ufa.evt_filt-events.lis
# HISTORY
# HISTORY F1 ./1050360103/xti/event_uf/ni1050360103_0mpu0_uf.evt[EVENTS][(gtifilte
# HISTORY F1 r("./1050360103/xti/event_cl/ni1050360103_0mpu0_ufa.evt_filt-evgti.gt
# HISTORY F1 TIME)&&(EVENT_FLAGS == bxxxx00))]
# HISTORY END FILE listing: ni1050360103_0mpu0_ufa.evt_filt-events.lis
# HISTORY
# HISTORY P2 outfile = ./1050360103/xti/event_cl/ni1050360103_0mpu0_ufa.evt_filt
# HISTORY P3 columns = *
# HISTORY P4 insertrow = 0
# HISTORY P5 lastkey =
# HISTORY P6 copyall = YES
# HISTORY P7 skipbadfiles = NO
# HISTORY P8 clobber = YES
# HISTORY P9 chatter = 1
# HISTORY P10 history = YES
# HISTORY P11 mode = ql
# HISTORY END PARAMETER list for ftmerge_2.20
# HISTORY
# TELAPSE = 1.116900000000000E+04 / elapsed time
# HISTORY
# HISTORY START PARAMETER list for nicerpi_interp_1.2 at 2018-03-06T19:16:04
# HISTORY
# HISTORY P1 infile = ./1050360103/xti/event_cl/ni1050360103_0mpu0_ufa.evt_filt
# HISTORY P2 outfile = ./1050360103/xti/event_cl/ni1050360103_0mpu0_ufa.evt_fastca
# HISTORY P2 l.interp
# HISTORY P3 hkfile = ./1050360103/xti/hk/ni1050360103_0mpu0.hk
# HISTORY P4 columns = MPU_A_TEMP,MPU_UNDER_COUNT
# HISTORY P5 existpolicy = OVERWRITE
# HISTORY P6 timeoffset = -0.5
# HISTORY P7 clobber = YES
# HISTORY P8 chatter = 0
# HISTORY P9 history = YES
# HISTORY P10 mode = ql
# HISTORY END PARAMETER list for nicerpi_interp_1.2
# HISTORY
# GAINAPP =                    T / Gain correction has been applied
# LONGSTRN= 'OGIP 1.0'           / The HEASARC Long String Convention may be used.
# COMMENT   This FITS file may contain long string keyword values that are
# COMMENT   continued over multiple keywords.  The HEASARC convention uses the &
# COMMENT   character at the end of each substring which is then continued
# COMMENT   on the next keyword which has the name CONTINUE.
# GAINMETH= 'MPU(PULSE_GRID)+MPUPIN(MPU_A_TEMP(POLY),MPU_UNDER_COUNT(DARK_MV))+E&'
# CONTINUE  'CORR(RATIONAL2)'    / MPU pulse grid lookup + FPM linear
# GCALFILE= 'nixtiflightpi20170601v001.fits[1]' / Gain calibration file name
# HISTORY
# HISTORY START PARAMETER list for nicerpi1_1.16 at 2018-03-06T19:16:04
# HISTORY
# HISTORY P1 infile = ./1050360103/xti/event_cl/ni1050360103_0mpu0_ufa.evt_fastcal
# HISTORY P1 .interp
# HISTORY P2 calfile = /home/dtsops/caldb/prod/data/nicer/xti/bcf/gainfast/nixtifl
# HISTORY P2 ightpifast20170601v001.fits[1]
# HISTORY P3 outfile = ./1050360103/xti/event_cl/ni1050360103_0mpu0_ufa.evt_fastca
# HISTORY P3 l
# HISTORY P4 column = PI_FAST
# HISTORY P5 initialize = YES
# HISTORY P6 pigain = 0.010
# HISTORY P7 pioffset = 0.000
# HISTORY P8 auxcolumns = MPU_A_TEMP,MPU_UNDER_COUNT
# HISTORY P9 randomize = YES
# HISTORY P10 randomseed = 0
# HISTORY P11 clobber = YES
# HISTORY P12 chatter = 3
# HISTORY P13 history = YES
# HISTORY P14 mode = ql
# HISTORY END PARAMETER list for nicerpi1_1.16
# HISTORY
# HISTORY
# HISTORY START PARAMETER list for nicerpi_interp_1.2 at 2018-03-06T19:16:04
# HISTORY
# HISTORY P1 infile = ./1050360103/xti/event_cl/ni1050360103_0mpu0_ufa.evt_fastcal
# HISTORY P2 outfile = ./1050360103/xti/event_cl/ni1050360103_0mpu0_ufa.evt_slowca
# HISTORY P2 l.interp
# HISTORY P3 hkfile = ./1050360103/xti/hk/ni1050360103_0mpu0.hk
# HISTORY P4 columns = MPU_A_TEMP,MPU_UNDER_COUNT
# HISTORY P5 existpolicy = KEEP
# HISTORY P6 timeoffset = -0.5
# HISTORY P7 clobber = YES
# HISTORY P8 chatter = 0
# HISTORY P9 history = YES
# HISTORY P10 mode = ql
# HISTORY END PARAMETER list for nicerpi_interp_1.2
# HISTORY
# HISTORY
# HISTORY START PARAMETER list for nicerpi1_1.16 at 2018-03-06T19:16:04
# HISTORY
# HISTORY P1 infile = ./1050360103/xti/event_cl/ni1050360103_0mpu0_ufa.evt_slowcal
# HISTORY P1 .interp
# HISTORY P2 calfile = /home/dtsops/caldb/prod/data/nicer/xti/bcf/gain/nixtiflight
# HISTORY P2 pi20170601v001.fits[1]
# HISTORY P3 outfile = ./1050360103/xti/event_cl/ni1050360103_0mpu0_ufa.evt_slowca
# HISTORY P3 l
# HISTORY P4 column = PI
# HISTORY P5 initialize = YES
# HISTORY P6 pigain = 0.010
# HISTORY P7 pioffset = 0.000
# HISTORY P8 auxcolumns = MPU_A_TEMP,MPU_UNDER_COUNT
# HISTORY P9 randomize = YES
# HISTORY P10 randomseed = 0
# HISTORY P11 clobber = YES
# HISTORY P12 chatter = 3
# HISTORY P13 history = YES
# HISTORY P14 mode = ql
# HISTORY END PARAMETER list for nicerpi1_1.16
# HISTORY
# TIMEMETH= 'MPU(CONST)+TIMEZERO(-1)' / Constant MPU bias + Broadreach
# TCALFILE= 'nixtitimebias20170901v002.fits[1]' / TIME calibration file name
# HISTORY
# HISTORY START PARAMETER list for nicertimecal1_1.2 at 2018-03-06T19:16:04
# HISTORY
# HISTORY P1 infile = ./1050360103/xti/event_cl/ni1050360103_0mpu0_ufa.evt_slowcal
# HISTORY P2 calfile = /home/dtsops/caldb/prod/data/nicer/xti/bcf/timebias/nixtiti
# HISTORY P2 mebias20170901v002.fits[1]
# HISTORY P3 outfile = ./1050360103/xti/event_cl/ni1050360103_0mpu0_ufa.evt_timeca
# HISTORY P3 l
# HISTORY P4 auxcolumns = NONE
# HISTORY P5 clobber = YES
# HISTORY P6 chatter = 3
# HISTORY P7 history = YES
# HISTORY P8 mode = ql
# HISTORY END PARAMETER list for nicertimecal1_1.2
# HISTORY
# HISTORY CFITSIO used the following filtering expression to create this table:
# HISTORY ./1050360103/xti/event_cl/ni1050360103_0mpu0_ufa.evt[EVENTS][(gtifilter(
# HISTORY "./1050360103/xti/event_cl/ni1050360103_0mpu7_ufa.evt_unsort-evgti.gti",
# HISTORY TIME))]
# HISTORY
# HISTORY START PARAMETER list for ftmerge_2.20 at 2018-03-06T19:16:10
# HISTORY
# HISTORY P1 (infile = @./1050360103/xti/event_cl/ni1050360103_0mpu7_ufa.evt_unsor
# HISTORY P1 t-events.lis)
# HISTORY
# HISTORY START FILE listing: ni1050360103_0mpu7_ufa.evt_unsort-events.lis
# HISTORY
# HISTORY F1 ./1050360103/xti/event_cl/ni1050360103_0mpu0_ufa.evt[EVENTS][(gtifilt
# HISTORY F1 er("./1050360103/xti/event_cl/ni1050360103_0mpu7_ufa.evt_unsort-evgti
# HISTORY F1 i",TIME))]
# HISTORY F2 ./1050360103/xti/event_cl/ni1050360103_0mpu1_ufa.evt[EVENTS][(gtifilt
# HISTORY F2 er("./1050360103/xti/event_cl/ni1050360103_0mpu7_ufa.evt_unsort-evgti
# HISTORY F2 i",TIME))]
# HISTORY F3 ./1050360103/xti/event_cl/ni1050360103_0mpu2_ufa.evt[EVENTS][(gtifilt
# HISTORY F3 er("./1050360103/xti/event_cl/ni1050360103_0mpu7_ufa.evt_unsort-evgti
# HISTORY F3 i",TIME))]
# HISTORY F4 ./1050360103/xti/event_cl/ni1050360103_0mpu3_ufa.evt[EVENTS][(gtifilt
# HISTORY F4 er("./1050360103/xti/event_cl/ni1050360103_0mpu7_ufa.evt_unsort-evgti
# HISTORY F4 i",TIME))]
# HISTORY F5 ./1050360103/xti/event_cl/ni1050360103_0mpu4_ufa.evt[EVENTS][(gtifilt
# HISTORY F5 er("./1050360103/xti/event_cl/ni1050360103_0mpu7_ufa.evt_unsort-evgti
# HISTORY F5 i",TIME))]
# HISTORY F6 ./1050360103/xti/event_cl/ni1050360103_0mpu5_ufa.evt[EVENTS][(gtifilt
# HISTORY F6 er("./1050360103/xti/event_cl/ni1050360103_0mpu7_ufa.evt_unsort-evgti
# HISTORY F6 i",TIME))]
# HISTORY F7 ./1050360103/xti/event_cl/ni1050360103_0mpu6_ufa.evt[EVENTS][(gtifilt
# HISTORY F7 er("./1050360103/xti/event_cl/ni1050360103_0mpu7_ufa.evt_unsort-evgti
# HISTORY F7 i",TIME))]
# HISTORY END FILE listing: ni1050360103_0mpu7_ufa.evt_unsort-events.lis
# HISTORY
# HISTORY P2 outfile = ./1050360103/xti/event_cl/ni1050360103_0mpu7_ufa.evt_unsort
# HISTORY P3 columns = *
# HISTORY P4 insertrow = 0
# HISTORY P5 lastkey =
# HISTORY P6 copyall = YES
# HISTORY P7 skipbadfiles = NO
# HISTORY P8 clobber = YES
# HISTORY P9 chatter = 1
# HISTORY P10 history = YES
# HISTORY P11 mode = ql
# HISTORY END PARAMETER list for ftmerge_2.20
# HISTORY
# FILIN002= './1050360103/xti/event_cl/ni1050360103_0mpu1_ufa.evt'
# FILIN003= './1050360103/xti/event_cl/ni1050360103_0mpu2_ufa.evt'
# FILIN004= './1050360103/xti/event_cl/ni1050360103_0mpu3_ufa.evt'
# FILIN005= './1050360103/xti/event_cl/ni1050360103_0mpu4_ufa.evt'
# FILIN006= './1050360103/xti/event_cl/ni1050360103_0mpu5_ufa.evt'
# FILIN007= './1050360103/xti/event_cl/ni1050360103_0mpu6_ufa.evt'
# HISTORY CFITSIO used the following filtering expression to create this table:
# HISTORY ./1050360103/xti/event_cl/ni1050360103_0mpu7_ufa.evt[EVENTS][(gtifilter(
# HISTORY "./1050360103/xti/event_cl/ni1050360103_0mpu7_cl.evt-totgti.gti",TIME)&&
# HISTORY (PI >= 20)&&(PI <= 1500)&&(EVENT_FLAGS == bx1x000)&&((DEFNULL(PI_RATIO,1
# HISTORY )<1.100000+120.000000/PI+0.000000e+00*PI**4)))][col *;PI==PI;TLMIN#=0;TL
# HISTORY MAX#=1500]
# HISTORY
# HISTORY START PARAMETER list for ftmerge_2.20 at 2018-03-06T19:16:14
# HISTORY
# HISTORY P1 (infile = @./1050360103/xti/event_cl/ni1050360103_0mpu7_cl.evt-events
# HISTORY P1 .lis)
# HISTORY
# HISTORY START FILE listing: ni1050360103_0mpu7_cl.evt-events.lis
# HISTORY
# HISTORY F1 ./1050360103/xti/event_cl/ni1050360103_0mpu7_ufa.evt[EVENTS][(gtifilt
# HISTORY F1 er("./1050360103/xti/event_cl/ni1050360103_0mpu7_cl.evt-totgti.gti",T
# HISTORY F1 )&&(PI >= 20)&&(PI <= 1500)&&(EVENT_FLAGS == bx1x000)&&((DEFNULL(PI_R
# HISTORY F1 O,1)<1.100000+120.000000/PI+0.000000e+00*PI**4)))][col *;PI==PI;TLMIN
# HISTORY F1 ;TLMAX#=1500]
# HISTORY END FILE listing: ni1050360103_0mpu7_cl.evt-events.lis
# HISTORY
# HISTORY P2 outfile = ./1050360103/xti/event_cl/ni1050360103_0mpu7_cl.evt
# HISTORY P3 columns = *
# HISTORY P4 insertrow = 0
# HISTORY P5 lastkey =
# HISTORY P6 copyall = YES
# HISTORY P7 skipbadfiles = NO
# HISTORY P8 clobber = YES
# HISTORY P9 chatter = 1
# HISTORY P10 history = YES
# HISTORY P11 mode = ql
# HISTORY END PARAMETER list for ftmerge_2.20
# HISTORY
# FILIN001= 'ni1050360103_0mpu7_cl.evt' / Input file name
# HDUCLAS2= 'TOTAL   '
# HDUCLAS3= 'RATE    '
# DETNAM  = 'NONE    '           / Detector
# LIVETIME= 1.330000000000000E+02 / On-source time
# MJD-OBS = 5.800530577759259E+04 / MJD of data start time
# USER    = 'ludde   '           / User name of creator
# PHALCUT =                  500 / Minimum PI channel
# PHAHCUT =                  549 / Maximum PI channel
# NPIXSOU =     5.6000000000E+01 / Numbers of Pixels
# MINFREXP=     9.9000000000E-01 / Minimum value of FRACEXP included
# HISTORY extractor v5.39
# CHECKSUM= 'jfaamZUajdZajZZa'   / HDU checksum updated 2021-12-08T09:40:53
# DATASUM = '2828069219'         / data unit checksum updated 2021-12-08T09:40:53
#
#         TIME           RATE    ERROR    FRACEXP
# -------------------- -------- -------- ----------
#                  0.0      0.0      0.0 0.99999905
# 0.004999995231628418 200.0002 200.0002 0.99999905
#  0.01000000536441803 200.0002 200.0002 0.99999905
# 0.015000000596046448      0.0      0.0 0.99999905
# 0.019999995827674866      0.0      0.0 0.99999905
# 0.025000005960464478      0.0      0.0 0.99999905
# 0.030000001192092896 400.0004  282.843 0.99999905
# 0.034999996423721313      0.0      0.0 0.99999905
# 0.040000006556510925 200.0002 200.0002 0.99999905
#  0.04500000178813934 200.0002 200.0002 0.99999905
#
# Loading fits done.

# %% [markdown]
# **If we want to extract more keywords from fits-file we can do like this:**

# %%
data = extract_fits(filename,keywords=['EQUINOX','TELESCOP'],p=0) 
print('\nTELESCOPE = ',data['TELESCOP'])
print('EQUINOX = ',data['EQUINOX'])
# Out:
# Loading fits from filename:  Data/MAXIJ1535_571/1050360103/5to5.5kev.lc
# There is no content-information for this fits.
# Found key EQUINOX in header0
# Found key EQUINOX in header1.
# Found key TELESCOP in header0
# Found key TELESCOP in header1.
# The keys to the data are: dict_keys(['TIME', 'RATE', 'ERROR', 'FRACEXP', 'OBJECT', 'EQUINOX', 'TELESCOP'])
# Loading fits done.
#
#
# TELESCOPE =  NICER
# EQUINOX =  2000.0

# %% [markdown]
# **If our keyword is not in any header, we will get suggestions:**

# %%
data = extract_fits(filename,keywords=['TELE'],p=0)
# Out:
# Loading fits from filename:  Data/MAXIJ1535_571/1050360103/5to5.5kev.lc
# There is no content-information for this fits.
# There is no key TELE in header0, let's have a look at header1.
# There is no key TELE in header1 either, sorry...
# Matching keys in header0 =  ['TELESCOP']
# Matching keys in header1 =  ['TELESCOP']
# Do you want to extract the header0 key TELESCOP? [y/n]
# Do you want to extract the header1 key TELESCOP? [y/n]
# The keys to the data are: dict_keys(['TIME', 'RATE', 'ERROR', 'FRACEXP', 'OBJECT'])
# Loading fits done.

# %%
# We now have the following keywords:
for keys in data:
    print(keys)
# Out:
# TIME
# RATE
# ERROR
# FRACEXP
# OBJECT

# %% [markdown]
# # Import FITS-file to Lightcurve-object directly:

# %%
filename = "Data/MAXIJ1535_571/1050360103/5to5.5kev.lc" 
lc = lightcurve(filename,keywords=['MINCHAN','MAXCHAN'],p=0)
# Out:
# -----------------------------------------------------------------------------------------------------------
#                Importing lightcurve from f = Data/MAXIJ1535_571/1050360103/5to5.5kev.lc
# -----------------------------------------------------------------------------------------------------------
# Loading fits from filename:  Data/MAXIJ1535_571/1050360103/5to5.5kev.lc
# There is no content-information for this fits.
# There is no key MINCHAN in header0, let's have a look at header1.
# There is no key MINCHAN in header1 either, sorry...
# Matching keys in header0 =  []
# Matching keys in header1 =  []
# There is no key MAXCHAN in header0, let's have a look at header1.
# There is no key MAXCHAN in header1 either, sorry...
# Matching keys in header0 =  []
# Matching keys in header1 =  []
# The keys to the data are: dict_keys(['TIME', 'RATE', 'ERROR', 'FRACEXP', 'OBJECT'])
# Loading fits done.
#
# Light curve object for MAXIJ1535-571 in Eband = 5.0-5.5 keV created.
# With parameters: N = 26598, dt = 0.005, R = 117.3, and Fvar = 0.2529.
# -----------------------------------------------------------------------------------------------------------

# %%
pprint(vars(lc))
# Out:
# {'Emax': 5.5,
#  'Emean': 5.25,
#  'Emin': 5.0,
#  'Fvar': 0.25286876190981783,
#  'N': 26598,
#  'R': 117.30218,
#  'deltaE': 0.25,
#  'dt': 0.004999995231628418,
#  'err': array([  0.    , 200.0002, 200.0002, ...,   0.    ,   0.    ,   0.    ],
#       dtype=float32),
#  'fracexp': array([0.99999905, 0.99999905, 0.99999905, ..., 0.99999905, 0.99999905,
#        0.99999905], dtype=float32),
#  'object': 'MAXIJ1535-571',
#  'rate': array([  0.    , 200.0002, 200.0002, ...,   0.    ,   0.    ,   0.    ],
#       dtype=float32),
#  't': array([0.00000000e+00, 4.99999523e-03, 1.00000054e-02, ...,
#        1.11689848e+04, 1.11689898e+04, 1.11689948e+04])}

# %% [markdown]
# ## Look at light curve etc

# %%
lc.plot()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/opt/anaconda3/envs/star/lib/python3.8/site-packages/matplotlib/texmanager.py in _run_checked_subprocess(self, command, tex)
#     274         try:
# --> 275             report = subprocess.check_output(command,
#     276                                              cwd=self.texcache,
#
# ~/opt/anaconda3/envs/star/lib/python3.8/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     410
# --> 411     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     412                **kwargs).stdout
#
# ~/opt/anaconda3/envs/star/lib/python3.8/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     488
# --> 489     with Popen(*popenargs, **kwargs) as process:
#     490         try:
#
# ~/opt/anaconda3/envs/star/lib/python3.8/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     853
# --> 854             self._execute_child(args, executable, preexec_fn, close_fds,
#     855                                 pass_fds, cwd, env,
#
# ~/opt/anaconda3/envs/star/lib/python3.8/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1701                         err_msg = os.strerror(errno_num)
# -> 1702                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1703                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'latex'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# ~/opt/anaconda3/envs/star/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/opt/anaconda3/envs/star/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/opt/anaconda3/envs/star/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/opt/anaconda3/envs/star/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2191                            else suppress())
#    2192                     with ctx:
# -> 2193                         self.figure.draw(renderer)
#    2194
#    2195                     bbox_inches = self.figure.get_tightbbox(
#
# ~/opt/anaconda3/envs/star/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/envs/star/lib/python3.8/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1861
#    1862             self.patch.draw(renderer)
# -> 1863             mimage._draw_list_compositing_images(
#    1864                 renderer, self, artists, self.suppressComposite)
#    1865
#
# ~/opt/anaconda3/envs/star/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~/opt/anaconda3/envs/star/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/envs/star/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~/opt/anaconda3/envs/star/lib/python3.8/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2705                 artists.remove(spine)
#    2706
# -> 2707         self._update_title_position(renderer)
#    2708
#    2709         if not self.axison or inframe:
#
# ~/opt/anaconda3/envs/star/lib/python3.8/site-packages/matplotlib/axes/_base.py in _update_title_position(self, renderer)
#    2646                 _log.debug('top of axes not in the figure, so title not moved')
#    2647                 return
# -> 2648             if title.get_window_extent(renderer).ymin < top:
#    2649                 _, y = self.transAxes.inverted().transform((0, top))
#    2650                 title.set_position((x, y))
#
# ~/opt/anaconda3/envs/star/lib/python3.8/site-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     900
#     901         with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 902             bbox, info, descent = self._get_layout(self._renderer)
#     903             x, y = self.get_unitless_position()
#     904             x, y = self.get_transform().transform((x, y))
#
# ~/opt/anaconda3/envs/star/lib/python3.8/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     285
#     286         # Full vertical extent of font, including ascenders and descenders:
# --> 287         _, lp_h, lp_d = renderer.get_text_width_height_descent(
#     288             "lp", self._fontproperties,
#     289             ismath="TeX" if self.get_usetex() else False)
#
# ~/opt/anaconda3/envs/star/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     225             texmanager = self.get_texmanager()
#     226             fontsize = prop.get_size_in_points()
# --> 227             w, h, d = texmanager.get_text_width_height_descent(
#     228                 s, fontsize, renderer=self)
#     229             return w, h, d
#
# ~/opt/anaconda3/envs/star/lib/python3.8/site-packages/matplotlib/texmanager.py in get_text_width_height_descent(self, tex, fontsize, renderer)
#     421         else:
#     422             # use dviread.
# --> 423             dvifile = self.make_dvi(tex, fontsize)
#     424             with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
#     425                 page, = dvi
#
# ~/opt/anaconda3/envs/star/lib/python3.8/site-packages/matplotlib/texmanager.py in make_dvi(self, tex, fontsize)
#     307             texfile = self.make_tex(tex, fontsize)
#     308             with cbook._lock_path(texfile):
# --> 309                 self._run_checked_subprocess(
#     310                     ["latex", "-interaction=nonstopmode", "--halt-on-error",
#     311                      texfile], tex)
#
# ~/opt/anaconda3/envs/star/lib/python3.8/site-packages/matplotlib/texmanager.py in _run_checked_subprocess(self, command, tex)
#     277                                              stderr=subprocess.STDOUT)
#     278         except FileNotFoundError as exc:
# --> 279             raise RuntimeError(
#     280                 'Failed to process string with tex because {} could not be '
#     281                 'found'.format(command[0])) from exc
#
# RuntimeError: Failed to process string with tex because latex could not be found

# %%
import latex
